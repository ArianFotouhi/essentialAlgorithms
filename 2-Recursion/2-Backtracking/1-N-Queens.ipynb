# %% [markdown]
# # N-Queens
#
# The n-queens puzzle is the problem of placing **n** queens on an **n x n** chessboard such that no two queens attack each other.
#
# Given an integer **n**, return all distinct solutions to the **n-queens** puzzle. You may return the answer in any order.
#
# Each solution contains a distinct board configuration of the **n-queens'** placement, where **'Q'** and **'.'** both indicate a queen and an empty space, respectively.

# %% [markdown]
# # Base Code

# %%
def solveNQueens(n: int):
    # Track which columns and diagonals are already occupied by queens.
    # 'cols' holds used column indices c
    # 'diag' holds used main diagonals identified by (r - c)
    # 'anti' holds used anti-diagonals identified by (r + c)
    cols, diag, anti = set(), set(), set()

    # Mutable board for building solutions; "." = empty, "Q" = queen.
    # Using a list of lists makes it easy to place/remove queens.
    board = [["."] * n for _ in range(n)]

    # Collect all valid board configurations here (as list[str]).
    res = []

    def backtrack(r: int):

        #return the board visualizer (final step)
        # If we've placed queens in all rows, we found a full solution.
        #activate when the final answer of this problem is ready
        if r == n:
            # Join each row list into a string snapshot and save it.
            res.append(["".join(row) for row in board])
            return

        # Try to place a queen in each column of the current row r.
        for c in range(n):
            # Skip this column if it conflicts with an existing queen:
            # same column, same (r-c) diagonal, or same (r+c) anti-diagonal.
            if c in cols or (r - c) in diag or (r + c) in anti:
                continue

            # Choose: place a queen at (r, c) and mark the constraints.
            # A constraint is set by this c and r
            cols.add(c)
            diag.add(r - c)
            anti.add(r + c)
            board[r][c] = "Q"

            # Recurse to the next row.
            #we go one step deeper r -> r+1
            #if all goes when we go deeper and deeper successfuly and no backtrack happens
            #so we stay on this line (backtrack(r+1)) for all the deeper levels and last layer returns the condition of r==n
            backtrack(r + 1)

            # Undo (backtrack): remove the queen and unmark constraints.
            #we remove the contraint because we are backtracking
            board[r][c] = "."
            cols.remove(c)
            diag.remove(r - c)
            anti.remove(r + c)

    # Start placing queens from the first row.
    backtrack(0)
    return res

# example:
solutions = solveNQueens(4)
for b in solutions:
    print("\n".join(b), "\n")
# Out:
# .Q..
# ...Q
# Q...
# ..Q.
#
# ..Q.
# Q...
# ...Q
# .Q..

# %% [markdown]
# # Versbose Printing

# %%
from typing import List, Set

class LimitReached(Exception):
    pass

class FirstSolutionFound(Exception):
    pass

def solve_n_queens_verbose(
    n: int,
    *,
    limit: int | None = None,          # max number of steps to print (None = unlimited)
    stop_after_first: bool = False      # stop as soon as a solution is found
) -> List[List[str]]:
    """
    Verbose N-Queens solver with step-by-step tracing.

    Actions:
      - TRY:       considering placing a queen at (r, c)
      - CONFLICT:  that (r, c) is unsafe (reason shown)
      - PLACE:     placed a queen at (r, c)
      - BACKTRACK: removed queen from (r, c) while unwinding
      - SOLUTION:  a full board (all rows filled) was found

    Vars:
      - cols: set of used columns
      - d1:   set of used major-diagonals (r - c)
      - d2:   set of used minor-diagonals (r + c)
      - board: list where board[r] = c (or -1 if empty)
    """
    solutions: List[List[str]] = []
    cols: Set[int] = set()
    d1: Set[int] = set()  # r - c
    d2: Set[int] = set()  # r + c
    board = [-1] * n
    step = 0

    def board_rows() -> List[str]:
        rows = []
        for rr in range(n):
            cc = board[rr]
            if cc == -1:
                rows.append("." * n)
            else:
                row = ["." for _ in range(n)]
                row[cc] = "Q"
                rows.append("".join(row))
        return rows

    def print_state(depth: int, action: str, r: int | None, c: int | None, note: str | None = None):
        nonlocal step
        step += 1
        indent = "  " * depth
        where = f" @ (r={r}, c={c})" if r is not None and c is not None else ""
        print(f"{indent}[{step}] {action}{where}")
        if note:
            print(f"{indent}    note: {note}")
        print(f"{indent}    cols={sorted(cols)}  d1(r-c)={sorted(d1)}  d2(r+c)={sorted(d2)}")
        print(f"{indent}    board={board}")
        for row in board_rows():
            print(f"{indent}      {row}")
        if limit is not None and step >= limit:
            raise LimitReached(f"Step limit reached ({limit}).")

    def snapshot_solution() -> List[str]:
        return board_rows()

    def backtrack(r: int, depth: int):
        # If all rows filled, we have a solution
        if r == n:
            print_state(depth, "SOLUTION", None, None, note="All rows placed")
            solutions.append(snapshot_solution())
            if stop_after_first:
                raise FirstSolutionFound
            return

        # Try all columns in this row
        for c in range(n):
            print_state(depth, "TRY", r, c)

            conflict_reasons = []
            if c in cols:
                conflict_reasons.append("same col")
            if (r - c) in d1:
                conflict_reasons.append("same diag1 (r-c)")
            if (r + c) in d2:
                conflict_reasons.append("same diag2 (r+c)")

            if conflict_reasons:
                print_state(depth, "CONFLICT", r, c, note=" & ".join(conflict_reasons))
                continue

            # Choose
            cols.add(c); d1.add(r - c); d2.add(r + c); board[r] = c
            print_state(depth, "PLACE", r, c)

            # Explore
            backtrack(r + 1, depth + 1)

            # Un-choose
            cols.remove(c); d1.remove(r - c); d2.remove(r + c); board[r] = -1
            print_state(depth, "BACKTRACK", r, c)

    print(f"--- N-Queens Backtracking Trace (n={n}) ---")
    try:
        backtrack(0, 0)
    except LimitReached as e:
        print(str(e))
    except FirstSolutionFound:
        print("--- Stopped after the first solution as requested ---")

    print(f"--- Found {len(solutions)} solution(s) ---")
    for i, sol in enumerate(solutions, 1):
        print(f"Solution {i}:")
        for row in sol:
            print("  " + row)
    return solutions


solve_n_queens_verbose(4,)
# Out:
# --- N-Queens Backtracking Trace (n=4) ---
# [1] TRY @ (r=0, c=0)
#     cols=[]  d1(r-c)=[]  d2(r+c)=[]
#     board=[-1, -1, -1, -1]
#       ....
#       ....
#       ....
#       ....
# [2] PLACE @ (r=0, c=0)
#     cols=[0]  d1(r-c)=[0]  d2(r+c)=[0]
#     board=[0, -1, -1, -1]
#       Q...
#       ....
#       ....
#       ....
#   [3] TRY @ (r=1, c=0)
#       cols=[0]  d1(r-c)=[0]  d2(r+c)=[0]
#       board=[0, -1, -1, -1]
#         Q...
#         ....
#         ....
#         ....
#   [4] CONFLICT @ (r=1, c=0)
#       note: same col
#       cols=[0]  d1(r-c)=[0]  d2(r+c)=[0]
#       board=[0, -1, -1, -1]
#         Q...
#         ....
#         ....
#         ....
#   [5] TRY @ (r=1, c=1)
#       cols=[0]  d1(r-c)=[0]  d2(r+c)=[0]
#       board=[0, -1, -1, -1]
#         Q...
#         ....
#         ....
#         ....
#   [6] CONFLICT @ (r=1, c=1)
#       note: same diag1 (r-c)
#       cols=[0]  d1(r-c)=[0]  d2(r+c)=[0]
#       board=[0, -1, -1, -1]
#         Q...
#         ....
#         ....
#         ....
#   [7] TRY @ (r=1, c=2)
#       cols=[0]  d1(r-c)=[0]  d2(r+c)=[0]
#       board=[0, -1, -1, -1]
#         Q...
#         ....
#         ....
#         ....
#   [8] PLACE @ (r=1, c=2)
#       cols=[0, 2]  d1(r-c)=[-1, 0]  d2(r+c)=[0, 3]
#       board=[0, 2, -1, -1]
#         Q...
#         ..Q.
#         ....
#         ....
#     [9] TRY @ (r=2, c=0)
#         cols=[0, 2]  d1(r-c)=[-1, 0]  d2(r+c)=[0, 3]
#         board=[0, 2, -1, -1]
#           Q...
#           ..Q.
#           ....
#           ....
#     [10] CONFLICT @ (r=2, c=0)
#         note: same col
#         cols=[0, 2]  d1(r-c)=[-1, 0]  d2(r+c)=[0, 3]
#         board=[0, 2, -1, -1]
#           Q...
#           ..Q.
#           ....
#           ....
#     [11] TRY @ (r=2, c=1)
#         cols=[0, 2]  d1(r-c)=[-1, 0]  d2(r+c)=[0, 3]
#         board=[0, 2, -1, -1]
#           Q...
#           ..Q.
#           ....
#           ....
#     [12] CONFLICT @ (r=2, c=1)
#         note: same diag2 (r+c)
#         cols=[0, 2]  d1(r-c)=[-1, 0]  d2(r+c)=[0, 3]
#         board=[0, 2, -1, -1]
#           Q...
#           ..Q.
#           ....
#           ....
#     [13] TRY @ (r=2, c=2)
#         cols=[0, 2]  d1(r-c)=[-1, 0]  d2(r+c)=[0, 3]
#         board=[0, 2, -1, -1]
#           Q...
#           ..Q.
#           ....
#           ....
#     [14] CONFLICT @ (r=2, c=2)
#         note: same col & same diag1 (r-c)
#         cols=[0, 2]  d1(r-c)=[-1, 0]  d2(r+c)=[0, 3]
#         board=[0, 2, -1, -1]
#           Q...
#           ..Q.
#           ....
#           ....
#     [15] TRY @ (r=2, c=3)
#         cols=[0, 2]  d1(r-c)=[-1, 0]  d2(r+c)=[0, 3]
#         board=[0, 2, -1, -1]
#           Q...
#           ..Q.
#           ....
#           ....
#     [16] CONFLICT @ (r=2, c=3)
#         note: same diag1 (r-c)
#         cols=[0, 2]  d1(r-c)=[-1, 0]  d2(r+c)=[0, 3]
#         board=[0, 2, -1, -1]
#           Q...
#           ..Q.
#           ....
#           ....
#   [17] BACKTRACK @ (r=1, c=2)
#       cols=[0]  d1(r-c)=[0]  d2(r+c)=[0]
#       board=[0, -1, -1, -1]
#         Q...
#         ....
#         ....
#         ....
#   [18] TRY @ (r=1, c=3)
#       cols=[0]  d1(r-c)=[0]  d2(r+c)=[0]
#       board=[0, -1, -1, -1]
#         Q...
#         ....
#         ....
#         ....
#   [19] PLACE @ (r=1, c=3)
#       cols=[0, 3]  d1(r-c)=[-2, 0]  d2(r+c)=[0, 4]
#       board=[0, 3, -1, -1]
#         Q...
#         ...Q
#         ....
#         ....
#     [20] TRY @ (r=2, c=0)
#         cols=[0, 3]  d1(r-c)=[-2, 0]  d2(r+c)=[0, 4]
#         board=[0, 3, -1, -1]
#           Q...
#           ...Q
#           ....
#           ....
#     [21] CONFLICT @ (r=2, c=0)
#         note: same col
#         cols=[0, 3]  d1(r-c)=[-2, 0]  d2(r+c)=[0, 4]
#         board=[0, 3, -1, -1]
#           Q...
#           ...Q
#           ....
#           ....
#     [22] TRY @ (r=2, c=1)
#         cols=[0, 3]  d1(r-c)=[-2, 0]  d2(r+c)=[0, 4]
#         board=[0, 3, -1, -1]
#           Q...
#           ...Q
#           ....
#           ....
#     [23] PLACE @ (r=2, c=1)
#         cols=[0, 1, 3]  d1(r-c)=[-2, 0, 1]  d2(r+c)=[0, 3, 4]
#         board=[0, 3, 1, -1]
#           Q...
#           ...Q
#           .Q..
#           ....
#       [24] TRY @ (r=3, c=0)
#           cols=[0, 1, 3]  d1(r-c)=[-2, 0, 1]  d2(r+c)=[0, 3, 4]
#           board=[0, 3, 1, -1]
#             Q...
#             ...Q
#             .Q..
#             ....
#       [25] CONFLICT @ (r=3, c=0)
#           note: same col & same diag2 (r+c)
#           cols=[0, 1, 3]  d1(r-c)=[-2, 0, 1]  d2(r+c)=[0, 3, 4]
#           board=[0, 3, 1, -1]
#             Q...
#             ...Q
#             .Q..
#             ....
#       [26] TRY @ (r=3, c=1)
#           cols=[0, 1, 3]  d1(r-c)=[-2, 0, 1]  d2(r+c)=[0, 3, 4]
#           board=[0, 3, 1, -1]
#             Q...
#             ...Q
#             .Q..
#             ....
#       [27] CONFLICT @ (r=3, c=1)
#           note: same col & same diag2 (r+c)
#           cols=[0, 1, 3]  d1(r-c)=[-2, 0, 1]  d2(r+c)=[0, 3, 4]
#           board=[0, 3, 1, -1]
#             Q...
#             ...Q
#             .Q..
#             ....
#       [28] TRY @ (r=3, c=2)
#           cols=[0, 1, 3]  d1(r-c)=[-2, 0, 1]  d2(r+c)=[0, 3, 4]
#           board=[0, 3, 1, -1]
#             Q...
#             ...Q
#             .Q..
#             ....
#       [29] CONFLICT @ (r=3, c=2)
#           note: same diag1 (r-c)
#           cols=[0, 1, 3]  d1(r-c)=[-2, 0, 1]  d2(r+c)=[0, 3, 4]
#           board=[0, 3, 1, -1]
#             Q...
#             ...Q
#             .Q..
#             ....
#       [30] TRY @ (r=3, c=3)
#           cols=[0, 1, 3]  d1(r-c)=[-2, 0, 1]  d2(r+c)=[0, 3, 4]
#           board=[0, 3, 1, -1]
#             Q...
#             ...Q
#             .Q..
#             ....
#       [31] CONFLICT @ (r=3, c=3)
#           note: same col & same diag1 (r-c)
#           cols=[0, 1, 3]  d1(r-c)=[-2, 0, 1]  d2(r+c)=[0, 3, 4]
#           board=[0, 3, 1, -1]
#             Q...
#             ...Q
#             .Q..
#             ....
#     [32] BACKTRACK @ (r=2, c=1)
#         cols=[0, 3]  d1(r-c)=[-2, 0]  d2(r+c)=[0, 4]
#         board=[0, 3, -1, -1]
#           Q...
#           ...Q
#           ....
#           ....
#     [33] TRY @ (r=2, c=2)
#         cols=[0, 3]  d1(r-c)=[-2, 0]  d2(r+c)=[0, 4]
#         board=[0, 3, -1, -1]
#           Q...
#           ...Q
#           ....
#           ....
#     [34] CONFLICT @ (r=2, c=2)
#         note: same diag1 (r-c) & same diag2 (r+c)
#         cols=[0, 3]  d1(r-c)=[-2, 0]  d2(r+c)=[0, 4]
#         board=[0, 3, -1, -1]
#           Q...
#           ...Q
#           ....
#           ....
#     [35] TRY @ (r=2, c=3)
#         cols=[0, 3]  d1(r-c)=[-2, 0]  d2(r+c)=[0, 4]
#         board=[0, 3, -1, -1]
#           Q...
#           ...Q
#           ....
#           ....
#     [36] CONFLICT @ (r=2, c=3)
#         note: same col
#         cols=[0, 3]  d1(r-c)=[-2, 0]  d2(r+c)=[0, 4]
#         board=[0, 3, -1, -1]
#           Q...
#           ...Q
#           ....
#           ....
#   [37] BACKTRACK @ (r=1, c=3)
#       cols=[0]  d1(r-c)=[0]  d2(r+c)=[0]
#       board=[0, -1, -1, -1]
#         Q...
#         ....
#         ....
#         ....
# [38] BACKTRACK @ (r=0, c=0)
#     cols=[]  d1(r-c)=[]  d2(r+c)=[]
#     board=[-1, -1, -1, -1]
#       ....
#       ....
#       ....
#       ....
# [39] TRY @ (r=0, c=1)
#     cols=[]  d1(r-c)=[]  d2(r+c)=[]
#     board=[-1, -1, -1, -1]
#       ....
#       ....
#       ....
#       ....
# [40] PLACE @ (r=0, c=1)
#     cols=[1]  d1(r-c)=[-1]  d2(r+c)=[1]
#     board=[1, -1, -1, -1]
#       .Q..
#       ....
#       ....
#       ....
#   [41] TRY @ (r=1, c=0)
#       cols=[1]  d1(r-c)=[-1]  d2(r+c)=[1]
#       board=[1, -1, -1, -1]
#         .Q..
#         ....
#         ....
#         ....
#   [42] CONFLICT @ (r=1, c=0)
#       note: same diag2 (r+c)
#       cols=[1]  d1(r-c)=[-1]  d2(r+c)=[1]
#       board=[1, -1, -1, -1]
#         .Q..
#         ....
#         ....
#         ....
#   [43] TRY @ (r=1, c=1)
#       cols=[1]  d1(r-c)=[-1]  d2(r+c)=[1]
#       board=[1, -1, -1, -1]
#         .Q..
#         ....
#         ....
#         ....
#   [44] CONFLICT @ (r=1, c=1)
#       note: same col
#       cols=[1]  d1(r-c)=[-1]  d2(r+c)=[1]
#       board=[1, -1, -1, -1]
#         .Q..
#         ....
#         ....
#         ....
#   [45] TRY @ (r=1, c=2)
#       cols=[1]  d1(r-c)=[-1]  d2(r+c)=[1]
#       board=[1, -1, -1, -1]
#         .Q..
#         ....
#         ....
#         ....
#   [46] CONFLICT @ (r=1, c=2)
#       note: same diag1 (r-c)
#       cols=[1]  d1(r-c)=[-1]  d2(r+c)=[1]
#       board=[1, -1, -1, -1]
#         .Q..
#         ....
#         ....
#         ....
#   [47] TRY @ (r=1, c=3)
#       cols=[1]  d1(r-c)=[-1]  d2(r+c)=[1]
#       board=[1, -1, -1, -1]
#         .Q..
#         ....
#         ....
#         ....
#   [48] PLACE @ (r=1, c=3)
#       cols=[1, 3]  d1(r-c)=[-2, -1]  d2(r+c)=[1, 4]
#       board=[1, 3, -1, -1]
#         .Q..
#         ...Q
#         ....
#         ....
#     [49] TRY @ (r=2, c=0)
#         cols=[1, 3]  d1(r-c)=[-2, -1]  d2(r+c)=[1, 4]
#         board=[1, 3, -1, -1]
#           .Q..
#           ...Q
#           ....
#           ....
#     [50] PLACE @ (r=2, c=0)
#         cols=[0, 1, 3]  d1(r-c)=[-2, -1, 2]  d2(r+c)=[1, 2, 4]
#         board=[1, 3, 0, -1]
#           .Q..
#           ...Q
#           Q...
#           ....
#       [51] TRY @ (r=3, c=0)
#           cols=[0, 1, 3]  d1(r-c)=[-2, -1, 2]  d2(r+c)=[1, 2, 4]
#           board=[1, 3, 0, -1]
#             .Q..
#             ...Q
#             Q...
#             ....
#       [52] CONFLICT @ (r=3, c=0)
#           note: same col
#           cols=[0, 1, 3]  d1(r-c)=[-2, -1, 2]  d2(r+c)=[1, 2, 4]
#           board=[1, 3, 0, -1]
#             .Q..
#             ...Q
#             Q...
#             ....
#       [53] TRY @ (r=3, c=1)
#           cols=[0, 1, 3]  d1(r-c)=[-2, -1, 2]  d2(r+c)=[1, 2, 4]
#           board=[1, 3, 0, -1]
#             .Q..
#             ...Q
#             Q...
#             ....
#       [54] CONFLICT @ (r=3, c=1)
#           note: same col & same diag1 (r-c) & same diag2 (r+c)
#           cols=[0, 1, 3]  d1(r-c)=[-2, -1, 2]  d2(r+c)=[1, 2, 4]
#           board=[1, 3, 0, -1]
#             .Q..
#             ...Q
#             Q...
#             ....
#       [55] TRY @ (r=3, c=2)
#           cols=[0, 1, 3]  d1(r-c)=[-2, -1, 2]  d2(r+c)=[1, 2, 4]
#           board=[1, 3, 0, -1]
#             .Q..
#             ...Q
#             Q...
#             ....
#       [56] PLACE @ (r=3, c=2)
#           cols=[0, 1, 2, 3]  d1(r-c)=[-2, -1, 1, 2]  d2(r+c)=[1, 2, 4, 5]
#           board=[1, 3, 0, 2]
#             .Q..
#             ...Q
#             Q...
#             ..Q.
#         [57] SOLUTION
#             note: All rows placed
#             cols=[0, 1, 2, 3]  d1(r-c)=[-2, -1, 1, 2]  d2(r+c)=[1, 2, 4, 5]
#             board=[1, 3, 0, 2]
#               .Q..
#               ...Q
#               Q...
#               ..Q.
#       [58] BACKTRACK @ (r=3, c=2)
#           cols=[0, 1, 3]  d1(r-c)=[-2, -1, 2]  d2(r+c)=[1, 2, 4]
#           board=[1, 3, 0, -1]
#             .Q..
#             ...Q
#             Q...
#             ....
#       [59] TRY @ (r=3, c=3)
#           cols=[0, 1, 3]  d1(r-c)=[-2, -1, 2]  d2(r+c)=[1, 2, 4]
#           board=[1, 3, 0, -1]
#             .Q..
#             ...Q
#             Q...
#             ....
#       [60] CONFLICT @ (r=3, c=3)
#           note: same col
#           cols=[0, 1, 3]  d1(r-c)=[-2, -1, 2]  d2(r+c)=[1, 2, 4]
#           board=[1, 3, 0, -1]
#             .Q..
#             ...Q
#             Q...
#             ....
#     [61] BACKTRACK @ (r=2, c=0)
#         cols=[1, 3]  d1(r-c)=[-2, -1]  d2(r+c)=[1, 4]
#         board=[1, 3, -1, -1]
#           .Q..
#           ...Q
#           ....
#           ....
#     [62] TRY @ (r=2, c=1)
#         cols=[1, 3]  d1(r-c)=[-2, -1]  d2(r+c)=[1, 4]
#         board=[1, 3, -1, -1]
#           .Q..
#           ...Q
#           ....
#           ....
#     [63] CONFLICT @ (r=2, c=1)
#         note: same col
#         cols=[1, 3]  d1(r-c)=[-2, -1]  d2(r+c)=[1, 4]
#         board=[1, 3, -1, -1]
#           .Q..
#           ...Q
#           ....
#           ....
#     [64] TRY @ (r=2, c=2)
#         cols=[1, 3]  d1(r-c)=[-2, -1]  d2(r+c)=[1, 4]
#         board=[1, 3, -1, -1]
#           .Q..
#           ...Q
#           ....
#           ....
#     [65] CONFLICT @ (r=2, c=2)
#         note: same diag2 (r+c)
#         cols=[1, 3]  d1(r-c)=[-2, -1]  d2(r+c)=[1, 4]
#         board=[1, 3, -1, -1]
#           .Q..
#           ...Q
#           ....
#           ....
#     [66] TRY @ (r=2, c=3)
#         cols=[1, 3]  d1(r-c)=[-2, -1]  d2(r+c)=[1, 4]
#         board=[1, 3, -1, -1]
#           .Q..
#           ...Q
#           ....
#           ....
#     [67] CONFLICT @ (r=2, c=3)
#         note: same col & same diag1 (r-c)
#         cols=[1, 3]  d1(r-c)=[-2, -1]  d2(r+c)=[1, 4]
#         board=[1, 3, -1, -1]
#           .Q..
#           ...Q
#           ....
#           ....
#   [68] BACKTRACK @ (r=1, c=3)
#       cols=[1]  d1(r-c)=[-1]  d2(r+c)=[1]
#       board=[1, -1, -1, -1]
#         .Q..
#         ....
#         ....
#         ....
# [69] BACKTRACK @ (r=0, c=1)
#     cols=[]  d1(r-c)=[]  d2(r+c)=[]
#     board=[-1, -1, -1, -1]
#       ....
#       ....
#       ....
#       ....
# [70] TRY @ (r=0, c=2)
#     cols=[]  d1(r-c)=[]  d2(r+c)=[]
#     board=[-1, -1, -1, -1]
#       ....
#       ....
#       ....
#       ....
# [71] PLACE @ (r=0, c=2)
#     cols=[2]  d1(r-c)=[-2]  d2(r+c)=[2]
#     board=[2, -1, -1, -1]
#       ..Q.
#       ....
#       ....
#       ....
#   [72] TRY @ (r=1, c=0)
#       cols=[2]  d1(r-c)=[-2]  d2(r+c)=[2]
#       board=[2, -1, -1, -1]
#         ..Q.
#         ....
#         ....
#         ....
#   [73] PLACE @ (r=1, c=0)
#       cols=[0, 2]  d1(r-c)=[-2, 1]  d2(r+c)=[1, 2]
#       board=[2, 0, -1, -1]
#         ..Q.
#         Q...
#         ....
#         ....
#     [74] TRY @ (r=2, c=0)
#         cols=[0, 2]  d1(r-c)=[-2, 1]  d2(r+c)=[1, 2]
#         board=[2, 0, -1, -1]
#           ..Q.
#           Q...
#           ....
#           ....
#     [75] CONFLICT @ (r=2, c=0)
#         note: same col & same diag2 (r+c)
#         cols=[0, 2]  d1(r-c)=[-2, 1]  d2(r+c)=[1, 2]
#         board=[2, 0, -1, -1]
#           ..Q.
#           Q...
#           ....
#           ....
#     [76] TRY @ (r=2, c=1)
#         cols=[0, 2]  d1(r-c)=[-2, 1]  d2(r+c)=[1, 2]
#         board=[2, 0, -1, -1]
#           ..Q.
#           Q...
#           ....
#           ....
#     [77] CONFLICT @ (r=2, c=1)
#         note: same diag1 (r-c)
#         cols=[0, 2]  d1(r-c)=[-2, 1]  d2(r+c)=[1, 2]
#         board=[2, 0, -1, -1]
#           ..Q.
#           Q...
#           ....
#           ....
#     [78] TRY @ (r=2, c=2)
#         cols=[0, 2]  d1(r-c)=[-2, 1]  d2(r+c)=[1, 2]
#         board=[2, 0, -1, -1]
#           ..Q.
#           Q...
#           ....
#           ....
#     [79] CONFLICT @ (r=2, c=2)
#         note: same col
#         cols=[0, 2]  d1(r-c)=[-2, 1]  d2(r+c)=[1, 2]
#         board=[2, 0, -1, -1]
#           ..Q.
#           Q...
#           ....
#           ....
#     [80] TRY @ (r=2, c=3)
#         cols=[0, 2]  d1(r-c)=[-2, 1]  d2(r+c)=[1, 2]
#         board=[2, 0, -1, -1]
#           ..Q.
#           Q...
#           ....
#           ....
#     [81] PLACE @ (r=2, c=3)
#         cols=[0, 2, 3]  d1(r-c)=[-2, -1, 1]  d2(r+c)=[1, 2, 5]
#         board=[2, 0, 3, -1]
#           ..Q.
#           Q...
#           ...Q
#           ....
#       [82] TRY @ (r=3, c=0)
#           cols=[0, 2, 3]  d1(r-c)=[-2, -1, 1]  d2(r+c)=[1, 2, 5]
#           board=[2, 0, 3, -1]
#             ..Q.
#             Q...
#             ...Q
#             ....
#       [83] CONFLICT @ (r=3, c=0)
#           note: same col
#           cols=[0, 2, 3]  d1(r-c)=[-2, -1, 1]  d2(r+c)=[1, 2, 5]
#           board=[2, 0, 3, -1]
#             ..Q.
#             Q...
#             ...Q
#             ....
#       [84] TRY @ (r=3, c=1)
#           cols=[0, 2, 3]  d1(r-c)=[-2, -1, 1]  d2(r+c)=[1, 2, 5]
#           board=[2, 0, 3, -1]
#             ..Q.
#             Q...
#             ...Q
#             ....
#       [85] PLACE @ (r=3, c=1)
#           cols=[0, 1, 2, 3]  d1(r-c)=[-2, -1, 1, 2]  d2(r+c)=[1, 2, 4, 5]
#           board=[2, 0, 3, 1]
#             ..Q.
#             Q...
#             ...Q
#             .Q..
#         [86] SOLUTION
#             note: All rows placed
#             cols=[0, 1, 2, 3]  d1(r-c)=[-2, -1, 1, 2]  d2(r+c)=[1, 2, 4, 5]
#             board=[2, 0, 3, 1]
#               ..Q.
#               Q...
#               ...Q
#               .Q..
#       [87] BACKTRACK @ (r=3, c=1)
#           cols=[0, 2, 3]  d1(r-c)=[-2, -1, 1]  d2(r+c)=[1, 2, 5]
#           board=[2, 0, 3, -1]
#             ..Q.
#             Q...
#             ...Q
#             ....
#       [88] TRY @ (r=3, c=2)
#           cols=[0, 2, 3]  d1(r-c)=[-2, -1, 1]  d2(r+c)=[1, 2, 5]
#           board=[2, 0, 3, -1]
#             ..Q.
#             Q...
#             ...Q
#             ....
#       [89] CONFLICT @ (r=3, c=2)
#           note: same col & same diag1 (r-c) & same diag2 (r+c)
#           cols=[0, 2, 3]  d1(r-c)=[-2, -1, 1]  d2(r+c)=[1, 2, 5]
#           board=[2, 0, 3, -1]
#             ..Q.
#             Q...
#             ...Q
#             ....
#       [90] TRY @ (r=3, c=3)
#           cols=[0, 2, 3]  d1(r-c)=[-2, -1, 1]  d2(r+c)=[1, 2, 5]
#           board=[2, 0, 3, -1]
#             ..Q.
#             Q...
#             ...Q
#             ....
#       [91] CONFLICT @ (r=3, c=3)
#           note: same col
#           cols=[0, 2, 3]  d1(r-c)=[-2, -1, 1]  d2(r+c)=[1, 2, 5]
#           board=[2, 0, 3, -1]
#             ..Q.
#             Q...
#             ...Q
#             ....
#     [92] BACKTRACK @ (r=2, c=3)
#         cols=[0, 2]  d1(r-c)=[-2, 1]  d2(r+c)=[1, 2]
#         board=[2, 0, -1, -1]
#           ..Q.
#           Q...
#           ....
#           ....
#   [93] BACKTRACK @ (r=1, c=0)
#       cols=[2]  d1(r-c)=[-2]  d2(r+c)=[2]
#       board=[2, -1, -1, -1]
#         ..Q.
#         ....
#         ....
#         ....
#   [94] TRY @ (r=1, c=1)
#       cols=[2]  d1(r-c)=[-2]  d2(r+c)=[2]
#       board=[2, -1, -1, -1]
#         ..Q.
#         ....
#         ....
#         ....
#   [95] CONFLICT @ (r=1, c=1)
#       note: same diag2 (r+c)
#       cols=[2]  d1(r-c)=[-2]  d2(r+c)=[2]
#       board=[2, -1, -1, -1]
#         ..Q.
#         ....
#         ....
#         ....
#   [96] TRY @ (r=1, c=2)
#       cols=[2]  d1(r-c)=[-2]  d2(r+c)=[2]
#       board=[2, -1, -1, -1]
#         ..Q.
#         ....
#         ....
#         ....
#   [97] CONFLICT @ (r=1, c=2)
#       note: same col
#       cols=[2]  d1(r-c)=[-2]  d2(r+c)=[2]
#       board=[2, -1, -1, -1]
#         ..Q.
#         ....
#         ....
#         ....
#   [98] TRY @ (r=1, c=3)
#       cols=[2]  d1(r-c)=[-2]  d2(r+c)=[2]
#       board=[2, -1, -1, -1]
#         ..Q.
#         ....
#         ....
#         ....
#   [99] CONFLICT @ (r=1, c=3)
#       note: same diag1 (r-c)
#       cols=[2]  d1(r-c)=[-2]  d2(r+c)=[2]
#       board=[2, -1, -1, -1]
#         ..Q.
#         ....
#         ....
#         ....
# [100] BACKTRACK @ (r=0, c=2)
#     cols=[]  d1(r-c)=[]  d2(r+c)=[]
#     board=[-1, -1, -1, -1]
#       ....
#       ....
#       ....
#       ....
# [101] TRY @ (r=0, c=3)
#     cols=[]  d1(r-c)=[]  d2(r+c)=[]
#     board=[-1, -1, -1, -1]
#       ....
#       ....
#       ....
#       ....
# [102] PLACE @ (r=0, c=3)
#     cols=[3]  d1(r-c)=[-3]  d2(r+c)=[3]
#     board=[3, -1, -1, -1]
#       ...Q
#       ....
#       ....
#       ....
#   [103] TRY @ (r=1, c=0)
#       cols=[3]  d1(r-c)=[-3]  d2(r+c)=[3]
#       board=[3, -1, -1, -1]
#         ...Q
#         ....
#         ....
#         ....
#   [104] PLACE @ (r=1, c=0)
#       cols=[0, 3]  d1(r-c)=[-3, 1]  d2(r+c)=[1, 3]
#       board=[3, 0, -1, -1]
#         ...Q
#         Q...
#         ....
#         ....
#     [105] TRY @ (r=2, c=0)
#         cols=[0, 3]  d1(r-c)=[-3, 1]  d2(r+c)=[1, 3]
#         board=[3, 0, -1, -1]
#           ...Q
#           Q...
#           ....
#           ....
#     [106] CONFLICT @ (r=2, c=0)
#         note: same col
#         cols=[0, 3]  d1(r-c)=[-3, 1]  d2(r+c)=[1, 3]
#         board=[3, 0, -1, -1]
#           ...Q
#           Q...
#           ....
#           ....
#     [107] TRY @ (r=2, c=1)
#         cols=[0, 3]  d1(r-c)=[-3, 1]  d2(r+c)=[1, 3]
#         board=[3, 0, -1, -1]
#           ...Q
#           Q...
#           ....
#           ....
#     [108] CONFLICT @ (r=2, c=1)
#         note: same diag1 (r-c) & same diag2 (r+c)
#         cols=[0, 3]  d1(r-c)=[-3, 1]  d2(r+c)=[1, 3]
#         board=[3, 0, -1, -1]
#           ...Q
#           Q...
#           ....
#           ....
#     [109] TRY @ (r=2, c=2)
#         cols=[0, 3]  d1(r-c)=[-3, 1]  d2(r+c)=[1, 3]
#         board=[3, 0, -1, -1]
#           ...Q
#           Q...
#           ....
#           ....
#     [110] PLACE @ (r=2, c=2)
#         cols=[0, 2, 3]  d1(r-c)=[-3, 0, 1]  d2(r+c)=[1, 3, 4]
#         board=[3, 0, 2, -1]
#           ...Q
#           Q...
#           ..Q.
#           ....
#       [111] TRY @ (r=3, c=0)
#           cols=[0, 2, 3]  d1(r-c)=[-3, 0, 1]  d2(r+c)=[1, 3, 4]
#           board=[3, 0, 2, -1]
#             ...Q
#             Q...
#             ..Q.
#             ....
#       [112] CONFLICT @ (r=3, c=0)
#           note: same col & same diag2 (r+c)
#           cols=[0, 2, 3]  d1(r-c)=[-3, 0, 1]  d2(r+c)=[1, 3, 4]
#           board=[3, 0, 2, -1]
#             ...Q
#             Q...
#             ..Q.
#             ....
#       [113] TRY @ (r=3, c=1)
#           cols=[0, 2, 3]  d1(r-c)=[-3, 0, 1]  d2(r+c)=[1, 3, 4]
#           board=[3, 0, 2, -1]
#             ...Q
#             Q...
#             ..Q.
#             ....
#       [114] CONFLICT @ (r=3, c=1)
#           note: same diag2 (r+c)
#           cols=[0, 2, 3]  d1(r-c)=[-3, 0, 1]  d2(r+c)=[1, 3, 4]
#           board=[3, 0, 2, -1]
#             ...Q
#             Q...
#             ..Q.
#             ....
#       [115] TRY @ (r=3, c=2)
#           cols=[0, 2, 3]  d1(r-c)=[-3, 0, 1]  d2(r+c)=[1, 3, 4]
#           board=[3, 0, 2, -1]
#             ...Q
#             Q...
#             ..Q.
#             ....
#       [116] CONFLICT @ (r=3, c=2)
#           note: same col & same diag1 (r-c)
#           cols=[0, 2, 3]  d1(r-c)=[-3, 0, 1]  d2(r+c)=[1, 3, 4]
#           board=[3, 0, 2, -1]
#             ...Q
#             Q...
#             ..Q.
#             ....
#       [117] TRY @ (r=3, c=3)
#           cols=[0, 2, 3]  d1(r-c)=[-3, 0, 1]  d2(r+c)=[1, 3, 4]
#           board=[3, 0, 2, -1]
#             ...Q
#             Q...
#             ..Q.
#             ....
#       [118] CONFLICT @ (r=3, c=3)
#           note: same col & same diag1 (r-c)
#           cols=[0, 2, 3]  d1(r-c)=[-3, 0, 1]  d2(r+c)=[1, 3, 4]
#           board=[3, 0, 2, -1]
#             ...Q
#             Q...
#             ..Q.
#             ....
#     [119] BACKTRACK @ (r=2, c=2)
#         cols=[0, 3]  d1(r-c)=[-3, 1]  d2(r+c)=[1, 3]
#         board=[3, 0, -1, -1]
#           ...Q
#           Q...
#           ....
#           ....
#     [120] TRY @ (r=2, c=3)
#         cols=[0, 3]  d1(r-c)=[-3, 1]  d2(r+c)=[1, 3]
#         board=[3, 0, -1, -1]
#           ...Q
#           Q...
#           ....
#           ....
#     [121] CONFLICT @ (r=2, c=3)
#         note: same col
#         cols=[0, 3]  d1(r-c)=[-3, 1]  d2(r+c)=[1, 3]
#         board=[3, 0, -1, -1]
#           ...Q
#           Q...
#           ....
#           ....
#   [122] BACKTRACK @ (r=1, c=0)
#       cols=[3]  d1(r-c)=[-3]  d2(r+c)=[3]
#       board=[3, -1, -1, -1]
#         ...Q
#         ....
#         ....
#         ....
#   [123] TRY @ (r=1, c=1)
#       cols=[3]  d1(r-c)=[-3]  d2(r+c)=[3]
#       board=[3, -1, -1, -1]
#         ...Q
#         ....
#         ....
#         ....
#   [124] PLACE @ (r=1, c=1)
#       cols=[1, 3]  d1(r-c)=[-3, 0]  d2(r+c)=[2, 3]
#       board=[3, 1, -1, -1]
#         ...Q
#         .Q..
#         ....
#         ....
#     [125] TRY @ (r=2, c=0)
#         cols=[1, 3]  d1(r-c)=[-3, 0]  d2(r+c)=[2, 3]
#         board=[3, 1, -1, -1]
#           ...Q
#           .Q..
#           ....
#           ....
#     [126] CONFLICT @ (r=2, c=0)
#         note: same diag2 (r+c)
#         cols=[1, 3]  d1(r-c)=[-3, 0]  d2(r+c)=[2, 3]
#         board=[3, 1, -1, -1]
#           ...Q
#           .Q..
#           ....
#           ....
#     [127] TRY @ (r=2, c=1)
#         cols=[1, 3]  d1(r-c)=[-3, 0]  d2(r+c)=[2, 3]
#         board=[3, 1, -1, -1]
#           ...Q
#           .Q..
#           ....
#           ....
#     [128] CONFLICT @ (r=2, c=1)
#         note: same col & same diag2 (r+c)
#         cols=[1, 3]  d1(r-c)=[-3, 0]  d2(r+c)=[2, 3]
#         board=[3, 1, -1, -1]
#           ...Q
#           .Q..
#           ....
#           ....
#     [129] TRY @ (r=2, c=2)
#         cols=[1, 3]  d1(r-c)=[-3, 0]  d2(r+c)=[2, 3]
#         board=[3, 1, -1, -1]
#           ...Q
#           .Q..
#           ....
#           ....
#     [130] CONFLICT @ (r=2, c=2)
#         note: same diag1 (r-c)
#         cols=[1, 3]  d1(r-c)=[-3, 0]  d2(r+c)=[2, 3]
#         board=[3, 1, -1, -1]
#           ...Q
#           .Q..
#           ....
#           ....
#     [131] TRY @ (r=2, c=3)
#         cols=[1, 3]  d1(r-c)=[-3, 0]  d2(r+c)=[2, 3]
#         board=[3, 1, -1, -1]
#           ...Q
#           .Q..
#           ....
#           ....
#     [132] CONFLICT @ (r=2, c=3)
#         note: same col
#         cols=[1, 3]  d1(r-c)=[-3, 0]  d2(r+c)=[2, 3]
#         board=[3, 1, -1, -1]
#           ...Q
#           .Q..
#           ....
#           ....
#   [133] BACKTRACK @ (r=1, c=1)
#       cols=[3]  d1(r-c)=[-3]  d2(r+c)=[3]
#       board=[3, -1, -1, -1]
#         ...Q
#         ....
#         ....
#         ....
#   [134] TRY @ (r=1, c=2)
#       cols=[3]  d1(r-c)=[-3]  d2(r+c)=[3]
#       board=[3, -1, -1, -1]
#         ...Q
#         ....
#         ....
#         ....
#   [135] CONFLICT @ (r=1, c=2)
#       note: same diag2 (r+c)
#       cols=[3]  d1(r-c)=[-3]  d2(r+c)=[3]
#       board=[3, -1, -1, -1]
#         ...Q
#         ....
#         ....
#         ....
#   [136] TRY @ (r=1, c=3)
#       cols=[3]  d1(r-c)=[-3]  d2(r+c)=[3]
#       board=[3, -1, -1, -1]
#         ...Q
#         ....
#         ....
#         ....
#   [137] CONFLICT @ (r=1, c=3)
#       note: same col
#       cols=[3]  d1(r-c)=[-3]  d2(r+c)=[3]
#       board=[3, -1, -1, -1]
#         ...Q
#         ....
#         ....
#         ....
# [138] BACKTRACK @ (r=0, c=3)
#     cols=[]  d1(r-c)=[]  d2(r+c)=[]
#     board=[-1, -1, -1, -1]
#       ....
#       ....
#       ....
#       ....
# --- Found 2 solution(s) ---
# Solution 1:
#   .Q..
#   ...Q
#   Q...
#   ..Q.
# Solution 2:
#   ..Q.
#   Q...
#   ...Q
#   .Q..
# [['.Q..', '...Q', 'Q...', '..Q.'], ['..Q.', 'Q...', '...Q', '.Q..']]
